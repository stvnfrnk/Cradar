# %% [markdown]
# # Plotting examples

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from Cradar import Cradar
from lib.plot_functions import plot_radargram

crd1       = Cradar().load_awi_nc("C:\\Users\\Steven\\Seafile\\Orca\\Projects\\Yuting\\Data_20181013_01_016_standard.nc", read_agc=False)
crd1.Frame = "20181013_01_016"
crd1.add_distance()
crd1.clip_range(0, 10000, mode="twt")
crd1.get_layer_idx()

crd1S   = Cradar.twt2surface(crd1, padding=0)
crd1S_2 = Cradar.twt2surface(crd1, padding=50)


# crd2       = Cradar().load_awi_nc("Data_20181013_01_017_standard.nc", read_agc=False)
# crd2.Frame = "20181013_01_017"
# crd2.add_distance()
# crd2.clip_range(0, 20000, mode="twt")
# crd2.get_layer_idx()

# plt.figure(figsize=(8,8))
# plot_radargram( crd1, 
#                 ax=None,
#                 range_mode='twt',
#                 every_km_dist=10,
#                 every_m_elev=1000,
#                 every_twt=['ms', 10],
#                 plot_layers=True,
#                 markersize=0.2,
#                 show_legend=True,
#                 xlabels_as_int=True,
#                 ylabels_as_int=True,
#                 vline_list=[200, 400],
#                 fontsize=12,
#                 show_figure=True, 
#                 show_cbar=True,
#                 cmap='binary',
#                 vmin='',
#                 vmax='')

# make figure with subplots
f, (ax1, ax2) = plt.subplots(2, 1, sharey=False, figsize=(12,10))
plot_radargram( crd1S, 
                ax=ax1,
                range_mode='twt',
                every_km_dist=10,
                every_m_elev=1000,
                every_twt=['ms', 2],
                plot_layers=False,
                markersize=0.2,
                show_legend=True,
                xlabels_as_int=True,
                ylabels_as_int=True,
                #vline_list=[200, 400],
                fontsize=12,
                show_cbar=False,
                cmap='binary',
                vmin='',
                vmax='')

plot_radargram( crd1S_2, 
                ax=ax2,
                range_mode='twt',
                every_km_dist=10,
                every_m_elev=1000,
                every_twt=['ms', 2],
                plot_layers=False,
                markersize=0.2,
                show_legend=True,
                xlabels_as_int=True,
                ylabels_as_int=True,
                #vline_list=[200, 400],
                fontsize=12,
                show_cbar=False,
                cmap='binary',
                vmin='',
                vmax='')
# Out:
# ==> Loaded C:\Users\Steven\Seafile\Orca\Projects\Yuting\Data_20181013_01_016_standard.nc
# ==> Added Spacing and Distance.
# ==> Clipped in range: bins 0--499
# ... getting layer idx for Surface
# ... getting layer idx for Base
# ==> Now: pull2elevation...
# ... processed  1  of  3333  traces in 0.00 s
# ... processed  1001  of  3333  traces in 0.01 s
# ... processed  2001  of  3333  traces in 0.01 s
# ... processed  3001  of  3333  traces in 0.01 s
# ==> Now: pull2elevation...
# ... processed  1  of  3333  traces in 0.00 s
# ... processed  1001  of  3333  traces in 0.00 s
# ... processed  2001  of  3333  traces in 0.00 s
# ... processed  3001  of  3333  traces in 0.02 s
# C:\Users\Steven\Documents\GitHub\Cradar\lib\plot_functions.py:235: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# C:\Users\Steven\Documents\GitHub\Cradar\lib\plot_functions.py:235: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from Cradar import Cradar
from lib.plot_functions import plot_radargram, plot_map

test_pol = "C:\\Users\\Steven\\Seafile\\Orca\\Projects\\Yuting\\shapes\\testpol.shp"
measures = "C:\\Users\\Steven\\Seafile\\Orca\\Projects\\Yuting\\raster\\measures_mag_ant_clip_yuting.tif"

crd1       = Cradar().load_awi_nc("C:\\Users\\Steven\\Seafile\\Orca\\Projects\\Yuting\\Data_20181013_01_016_standard.nc", read_agc=False)
crd1.Frame = "20181013_01_016"
crd1.add_distance()
crd1.clip_range(0, 20000, mode="twt")
crd1.get_layer_idx()

crd2       = Cradar().load_awi_nc("C:\\Users\\Steven\\Seafile\\Orca\\Projects\\Yuting\\Data_20181013_01_017_standard.nc", read_agc=False)
crd2.Frame = "20181013_01_017"
crd2.add_distance()
crd2.clip_range(0, 20000, mode="twt")
crd2.get_layer_idx()


# make figure with subplots
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(
                                    ncols=2,
                                    nrows=2,
                                    figsize=(15, 8))

plot_map( crd1, 
          ax=ax1,
          flight_lines="",
          geotif=measures,
          epsg=3031)

plot_radargram( crd1, 
                ax=ax2,
                range_mode='twt',
                every_km_dist=10,
                every_m_elev=1000,
                every_twt=['ms', 10],
                plot_layers=True,
                markersize=0.2,
                show_legend=True,
                xlabels_as_int=True,
                ylabels_as_int=True,
                vline_list=[200, 400],
                fontsize=12,
                show_cbar=False,
                cmap='binary',
                vmin='',
                vmax='')

plot_map( crd2, 
          ax=ax3,
          flight_lines="",
          geotif=measures,
          epsg=3031)

plot_radargram( crd2,
                ax=ax4,
                range_mode='twt',
                every_km_dist=10,
                every_m_elev=1000,
                every_twt=['ms', 10],
                plot_layers=True,
                markersize=0.2,
                show_legend=True,
                xlabels_as_int=True,
                ylabels_as_int=True,
                vline_list=[200, 400],
                fontsize=12,
                show_cbar=False,
                cmap='binary',
                vmin='',
                vmax='')

plt.tight_layout()
plt.subplots_adjust(left=0.2, bottom=None, right=None, top=None, wspace=None, hspace=None)
# Out:
# ==> Loaded C:\Users\Steven\Seafile\Orca\Projects\Yuting\Data_20181013_01_016_standard.nc
# ==> Added Spacing and Distance.
# ==> Clipped in range: bins 0--999
# ... getting layer idx for Surface
# ... getting layer idx for Base
#
# ==> Loaded C:\Users\Steven\Seafile\Orca\Projects\Yuting\Data_20181013_01_017_standard.nc
# ==> Added Spacing and Distance.
# ==> Clipped in range: bins 0--999
# ... getting layer idx for Surface
# ... getting layer idx for Base
